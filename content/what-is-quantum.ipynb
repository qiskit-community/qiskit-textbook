# %% [markdown]
# # What is Quantum?

# %%
# This code is to create the interactive figure
from bokeh.events import ButtonClick
from bokeh.layouts import row, column
from bokeh.models import ColumnDataSource, CustomJS, Button, Slider, DataRange1d, LabelSet, RadioButtonGroup, Div
from bokeh.plotting import figure
from bokeh.embed import file_html
from bokeh.resources import CDN
from bokeh.io import output_notebook, show, curdoc
import IPython

# %% [markdown]
# ‘Quantum physics’ is a term widely used but much less understood. It is a mathematical model first used to describe the behavior of small things in a laboratory, which exposed gaps in the preceding theory of ‘classical’ physics. Quantum theory explains this behavior and gives us a more complete picture of our universe. We have realized we can use this previously unexplained behavior to perform certain computations that we previously did not believe possible. We call this quantum computing.
#
# Quantum computing is the perfect way to dip your toes into quantum physics. It distills the core concepts from quantum physics into their simplest forms, stripping away the complications of the physical world. This page will take you on a short journey to discover (and explain!) some strange quantum phenomena, and give you a taste for what ‘quantum’ is.

# %% [markdown]
# ## Review of Classical Probability
#
# To cover quantum phenomena, we need to first remind ourselves of 'classical' probabilities. In this sense, 'classical' just means pre-quantum, i.e. the normal probability trees you should have seen in school. If you're already familiar with this material, you should move through it quickly. If you're not so hot on this then don't worry- we'll only cover some of the simplest probability problems possible.
#
# ### Probability Trees
#
# You will hopefully remember probability trees from school. The idea is simple - we use a drawing to map out every possible eventuality and from this, we can calculate the chance of it happening.
#
# Say we have a coin, and to start, we place it in the state Heads. If we then toss this fair coin and look at it, there is a 50% chance we will see Heads again, and a 50% chance of seeing Tails instead. We can plot this on a probability tree like so:
#
# ![](images/whatis/whatis1.png)
#
# We draw the outcomes on the end of each branch, and the probabilities of each occurrence on the branches. Similarly, if we started in the state Tails and tossed the coin, we would have a 50% chance of seeing Heads and a 50% chance of seeing tails.
#
# ![](images/whatis/whatis2.png)
#
# We can test this works by trying it. You can physically get a coin out, flip it many times, and record each result; you will eventually see roughly 50% of your results are Heads and 50% tails. Around 500 to 1000 tosses should be enough to get reliable results.
#
# ### Experiment #1: Single Coin Toss
#
# Too lazy to try this? Don’t worry! You can simulate the coin-tossing experiment by pressing the `Toss Coin` button below to simulate a coin toss and store the results. You can change the initial state to 'Heads' or 'Tails', or increase the number of coins (`No. of Coins`) slider to get many results quickly. Click `Reset` to discard your results and start again.

# %%
data_labels = ["Heads", "Tails"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# Define buttons and sliders
tossbtn = Button(label="Toss Coin")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# Define callbacks
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' H ', ' T '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Coin";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Coins";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# Link callbacks to buttons / sliders
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# Compose Layout
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# Output HTML
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.1.1.min.js" integrity="sha384-kLr4fYcqcSpbuI95brIH3vnnYCquzzSxHPU6XGQCIkQRGJwhg0StNbj1eegrHs12" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.1.1.min.js" integrity="sha384-xIGPmVtaOm+z0BqfSOMn4lOR6ciex448GIKG4eE61LsAvmGj48XcMQZtKcE/UXZe" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="e40cc63c-27c4-429b-8ebe-0e834a5b1249" data-root-id="1039"></div>
#
#
#
#
#
#         <script type="application/json" id="1128">
#           {"18cd1361-f3d7-4187-9337-f06e4de51804":{"roots":{"references":[{"attributes":{"text":"Initial State:"},"id":"1030","type":"Div"},{"attributes":{"text":""},"id":"1040","type":"Title"},{"attributes":{"active":0,"labels":["Heads","Tails"],"name":"Initial State"},"id":"1031","type":"RadioButtonGroup"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"1002","type":"DataRange1d"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"1036"}]},"start":1,"title":"No. of Coins","value":0},"id":"1029","type":"Slider"},{"attributes":{"fill_color":{"value":"#BE95FF"},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1022","type":"VBar"},{"attributes":{"args":{"tossbtn":{"id":"1028"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Coin\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Coins\";\n    };\n    "},"id":"1036","type":"CustomJS"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1037"}]},"label":"Reset"},"id":"1032","type":"Button"},{"attributes":{},"id":"1018","type":"ResetTool"},{"attributes":{},"id":"1047","type":"UnionRenderers"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1018"}]},"id":"1019","type":"Toolbar"},{"attributes":{},"id":"1042","type":"BasicTickFormatter"},{"attributes":{},"id":"1046","type":"Selection"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"1034","type":"Div"},{"attributes":{"text":"Results:"},"id":"1033","type":"Div"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1023","type":"VBar"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["Heads","Tails"]},"selected":{"id":"1046"},"selection_policy":{"id":"1047"}},"id":"1001","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"1011"}],"center":[{"id":"1013"},{"id":"1017"},{"id":"1026"}],"left":[{"id":"1014"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"1024"}],"sizing_mode":"scale_width","title":{"id":"1040"},"toolbar":{"id":"1019"},"x_range":{"id":"1004"},"x_scale":{"id":"1007"},"y_range":{"id":"1002"},"y_scale":{"id":"1009"}},"id":"1003","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"1044"},"ticker":{"id":"1012"}},"id":"1011","type":"CategoricalAxis"},{"attributes":{},"id":"1044","type":"CategoricalTickFormatter"},{"attributes":{"args":{"p":{"id":"1003"},"resultsHTML":{"id":"1034"},"results_label":{"id":"1033"},"s":{"id":"1029"},"source":{"id":"1001"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = Math.floor(Math.random() * 2);\n            source.data.top[result] += 1;\n            resultsHTML.text += [' H ', ' T '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" tosses):\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_range.range_padding_units = 'percent';\n            p.y_range.range_padding = 1;\n        } else {\n            p.y_range.range_padding_units = 'absolute';\n            p.y_range.range_padding = 30 - Math.max(...source.data.top);\n        };\n        source.change.emit();\n    "},"id":"1035","type":"CustomJS"},{"attributes":{"args":{"resultsHTML":{"id":"1034"},"results_label":{"id":"1033"},"source":{"id":"1001"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0 ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('1128').textContent;
#                   var render_items = [{"docid":"18cd1361-f3d7-4187-9337-f06e4de51804","root_ids":["1039"],"roots":{"1039":"e40cc63c-27c4-429b-8ebe-0e834a5b1249"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         }

# %% [markdown]
# ### Going Further
#
# It looks like our probability tree model correctly predicts the results of our experiments. We can go further and chain our probability trees together to predict the outcomes of chains of events. For example, let’s say we start in the state Heads, toss the coin, then _toss the coin again,_ what would we see? We can work it out using the trees:
#
# ![](images/whatis/whatis3.png)
#
# You may remember from school that we multiply along the branches to calculate the probability of each combination of events:
#
# ![](images/whatis/whatis4.gif)
#
# We then add the results together to calculate the probability of each outcome:
#
# ![](images/whatis/whatis5.gif)
#
# And we can see the probability of seeing Heads after these two tosses is 50%, and the probability of seeing Tails after these two tosses is also 50%.
#
# ### Experiment #2: Double Coin Toss
#
# As with before, you can simulate the coin-tossing experiment by pressing the `Toss Coin Twice` button to simulate two coin tosses and store the final result. You can change the initial state, or change the `No. of Coins` to get many results quickly. Click `Reset` to discard your results and start again.

# %%
data_labels = ["Heads", "Tails"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# Define buttons and sliders
tossbtn = Button(label="Toss Coin Twice")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# Define callbacks
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' H ', ' T '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Double Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Coin Twice";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Coins Twice";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# Link callbacks to buttons / sliders
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# Compose Layout
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# Output HTML
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.1.1.min.js" integrity="sha384-kLr4fYcqcSpbuI95brIH3vnnYCquzzSxHPU6XGQCIkQRGJwhg0StNbj1eegrHs12" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.1.1.min.js" integrity="sha384-xIGPmVtaOm+z0BqfSOMn4lOR6ciex448GIKG4eE61LsAvmGj48XcMQZtKcE/UXZe" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="dbb454c9-baea-40aa-8480-ea25e66f8a7b" data-root-id="1167"></div>
#
#
#
#
#
#         <script type="application/json" id="1256">
#           {"9f821e63-ed2e-4c7d-b6ea-2b8de7ed656c":{"roots":{"references":[{"attributes":{"text":"Initial State:"},"id":"1158","type":"Div"},{"attributes":{},"id":"1137","type":"LinearScale"},{"attributes":{},"id":"1172","type":"CategoricalTickFormatter"},{"attributes":{"active":0,"labels":["Heads","Tails"],"name":"Initial State"},"id":"1159","type":"RadioButtonGroup"},{"attributes":{},"id":"1174","type":"Selection"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"1164"}]},"start":1,"title":"No. of Coins","value":0},"id":"1157","type":"Slider"},{"attributes":{},"id":"1170","type":"BasicTickFormatter"},{"attributes":{},"id":"1140","type":"CategoricalTicker"},{"attributes":{"args":{"p":{"id":"1131"},"resultsHTML":{"id":"1162"},"results_label":{"id":"1161"},"s":{"id":"1157"},"source":{"id":"1129"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = Math.floor(Math.random() * 2);\n            source.data.top[result] += 1;\n            resultsHTML.text += [' H ', ' T '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" Double Tosses):\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_range.range_padding_units = 'percent';\n            p.y_range.range_padding = 1;\n        } else {\n            p.y_range.range_padding_units = 'absolute';\n            p.y_range.range_padding = 30 - Math.max(...source.data.top);\n        };\n        source.change.emit();\n    "},"id":"1163","type":"CustomJS"},{"attributes":{"axis":{"id":"1139"},"ticker":null},"id":"1141","type":"Grid"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"1162","type":"Div"},{"attributes":{},"id":"1175","type":"UnionRenderers"},{"attributes":{"text":"Results:"},"id":"1161","type":"Div"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1151","type":"VBar"},{"attributes":{"args":{"resultsHTML":{"id":"1162"},"results_label":{"id":"1161"},"source":{"id":"1129"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"1165","type":"CustomJS"},{"attributes":{"args":{"tossbtn":{"id":"1156"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Coin Twice\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Coins Twice\";\n    };\n    "},"id":"1164","type":"CustomJS"},{"attributes":{"children":[{"id":"1131"},{"id":"1166"}]},"id":"1167","type":"Row"},{"attributes":{},"id":"1146","type":"ResetTool"},{"attributes":{"data_source":{"id":"1129"},"glyph":{"id":"1150"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1151"},"selection_glyph":null,"view":{"id":"1153"}},"id":"1152","type":"GlyphRenderer"},{"attributes":{"axis":{"id":"1142"},"dimension":1,"ticker":null},"id":"1145","type":"Grid"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["Heads","Tails"]},"selected":{"id":"1174"},"selection_policy":{"id":"1175"}},"id":"1129","type":"ColumnDataSource"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"1130","type":"DataRange1d"},{"attributes":{"children":[{"id":"1156"},{"id":"1157"},{"id":"1158"},{"id":"1159"},{"id":"1160"},{"id":"1161"},{"id":"1162"}]},"id":"1166","type":"Column"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1163"}]},"label":"Toss Coin Twice"},"id":"1156","type":"B ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('1256').textContent;
#                   var render_items = [{"docid":"9f821e63-ed2e-4c7d-b6ea-2b8de7ed656c","root_ids":["1167"],"roots":{"1167":"dbb454c9-baea-40aa-8480-ea25e66f8a7b"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");

# %% [markdown]
# With enough tosses, our results are as expected: Equal chance of measuring Heads or Tails.
#
# ## The Quantum Coin
#
# Now we have a complete description of the classical coin, it’s time to introduce a quantum ‘coin’. Our quantum coin is called a ‘qubit’.
#
# A qubit is something you can only play with in a lab, as they are very difficult to manipulate.  Many years of scientific and technological advancements have gone into creating the qubits we have today, but the beauty of learning through quantum computing is that we can ignore the physical complications and just remember that when we measure a qubit, it will be in one of two states: Instead of the two states Heads and Tails, we call our qubit’s two states 0 and 1.
#
# ### Experiment #3: The Quantum Coin Toss
#
# Let’s experiment with our quantum coin and see how it behaves. We’re going to do a quantum toss, measure the state of our coin, and record it. This is just like the classical coin toss in the section above.

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# Define buttons and sliders
tossbtn = Button(label="Toss Quantum Coin")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# Define callbacks
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Quantum Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# Link callbacks to buttons / sliders
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# Compose Layout
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# Output HTML
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.1.1.min.js" integrity="sha384-kLr4fYcqcSpbuI95brIH3vnnYCquzzSxHPU6XGQCIkQRGJwhg0StNbj1eegrHs12" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.1.1.min.js" integrity="sha384-xIGPmVtaOm+z0BqfSOMn4lOR6ciex448GIKG4eE61LsAvmGj48XcMQZtKcE/UXZe" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="0cef0c6e-60fa-4d21-bddb-45cbb88787af" data-root-id="1295"></div>
#
#
#
#
#
#         <script type="application/json" id="1384">
#           {"af2c50b2-ee37-4ff1-bebf-7fa8dd0276a5":{"roots":{"references":[{"attributes":{"text":""},"id":"1296","type":"Title"},{"attributes":{},"id":"1271","type":"BasicTicker"},{"attributes":{},"id":"1300","type":"CategoricalTickFormatter"},{"attributes":{"active":0,"labels":["0","1"],"name":"Initial State"},"id":"1287","type":"RadioButtonGroup"},{"attributes":{},"id":"1268","type":"CategoricalTicker"},{"attributes":{},"id":"1302","type":"Selection"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1293"}]},"label":"Reset"},"id":"1288","type":"Button"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1274"}]},"id":"1275","type":"Toolbar"},{"attributes":{"axis":{"id":"1267"},"ticker":null},"id":"1269","type":"Grid"},{"attributes":{},"id":"1298","type":"BasicTickFormatter"},{"attributes":{"axis":{"id":"1270"},"dimension":1,"ticker":null},"id":"1273","type":"Grid"},{"attributes":{"args":{"resultsHTML":{"id":"1290"},"results_label":{"id":"1289"},"source":{"id":"1257"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"1293","type":"CustomJS"},{"attributes":{"axis_label":"Counts","formatter":{"id":"1298"},"ticker":{"id":"1271"}},"id":"1270","type":"LinearAxis"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"1290","type":"Div"},{"attributes":{},"id":"1303","type":"UnionRenderers"},{"attributes":{"text":"Results:"},"id":"1289","type":"Div"},{"attributes":{"args":{"p":{"id":"1259"},"resultsHTML":{"id":"1290"},"results_label":{"id":"1289"},"s":{"id":"1285"},"source":{"id":"1257"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = Math.floor(Math.random() * 2);\n            source.data.top[result] += 1;\n            resultsHTML.text += [' 0 ', ' 1 '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" Quantum Tosses):\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_range.range_padding_units = 'percent';\n            p.y_range.range_padding = 1;\n        } else {\n            p.y_range.range_padding_units = 'absolute';\n            p.y_range.range_padding = 30 - Math.max(...source.data.top);\n        };\n        source.change.emit();\n    "},"id":"1291","type":"CustomJS"},{"attributes":{"level":"glyph","source":{"id":"1257"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"1282","type":"LabelSet"},{"attributes":{},"id":"1274","type":"ResetTool"},{"attributes":{"args":{"tossbtn":{"id":"1284"}},"code":"\n    const repeats = cb_obj.value;\n    if (repeats == 1) {\n        tossbtn.label = \"Toss Quantum Coin\";\n    }\n    else {\n        tossbtn.label = \"Toss \" + repeats + \" Quantum Coins\";\n    };\n    "},"id":"1292","type":"CustomJS"},{"attributes":{"children":[{"id":"1259"},{"id":"1294"}]},"id":"1295","type":"Row"},{"attributes":{"data_source":{"id":"1257"},"glyph":{"id":"1278"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1279"},"selection_glyph":null,"view":{"id":"1281"}},"id":"1280","type":"GlyphRenderer"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"1302"},"selection_policy":{"id":"1303"}},"id":"1257","type":"ColumnDataSource"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"1258","type":"DataRange1d"},{"attributes":{"source":{"id":"1257"}},"id":"1281","type":"CDSView"},{"attri ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('1384').textContent;
#                   var render_items = [{"docid":"af2c50b2-ee37-4ff1-bebf-7fa8dd0276a5","root_ids":["1295"],"roots":{"1295":"0cef0c6e-60fa-4d21-bddb-45cbb88787af"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         }

# %% [markdown]
# We’re going to try and describe our quantum coin using probability trees. This looks like, from a 0 state, the coin toss gives us a 50-50 chance of measuring 0 or 1. Let’s plot this on a tree as we did with the classical coin:
#
# ![](images/whatis/whatis6.png)

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# Define buttons and sliders
tossbtn = Button(label="Toss Quantum Coin")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=1)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# Define callbacks
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = Math.floor(Math.random() * 2);
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Quantum Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# Link callbacks to buttons / sliders
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# Compose Layout
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# Output HTML
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.1.1.min.js" integrity="sha384-kLr4fYcqcSpbuI95brIH3vnnYCquzzSxHPU6XGQCIkQRGJwhg0StNbj1eegrHs12" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.1.1.min.js" integrity="sha384-xIGPmVtaOm+z0BqfSOMn4lOR6ciex448GIKG4eE61LsAvmGj48XcMQZtKcE/UXZe" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="0719a5e0-3d1a-46bd-ad9c-9fc4d3010778" data-root-id="1423"></div>
#
#
#
#
#
#         <script type="application/json" id="1512">
#           {"18d8fab4-968d-4fa7-bbae-43bbb73378bd":{"roots":{"references":[{"attributes":{"factors":["0","1"]},"id":"1388","type":"FactorRange"},{"attributes":{"children":[{"id":"1387"},{"id":"1422"}]},"id":"1423","type":"Row"},{"attributes":{"below":[{"id":"1395"}],"center":[{"id":"1397"},{"id":"1401"},{"id":"1410"}],"left":[{"id":"1398"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"1408"}],"sizing_mode":"scale_width","title":{"id":"1424"},"toolbar":{"id":"1403"},"x_range":{"id":"1388"},"x_scale":{"id":"1391"},"y_range":{"id":"1386"},"y_scale":{"id":"1393"}},"id":"1387","subtype":"Figure","type":"Plot"},{"attributes":{"children":[{"id":"1412"},{"id":"1413"},{"id":"1414"},{"id":"1415"},{"id":"1416"},{"id":"1417"},{"id":"1418"}]},"id":"1422","type":"Column"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"1430"},"selection_policy":{"id":"1431"}},"id":"1385","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"1428"},"ticker":{"id":"1396"}},"id":"1395","type":"CategoricalAxis"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1421"}]},"label":"Reset"},"id":"1416","type":"Button"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1407","type":"VBar"},{"attributes":{},"id":"1391","type":"CategoricalScale"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1419"}]},"label":"Toss Quantum Coin"},"id":"1412","type":"Button"},{"attributes":{},"id":"1393","type":"LinearScale"},{"attributes":{"text":"Initial State:"},"id":"1414","type":"Div"},{"attributes":{"fill_color":{"value":"#BE95FF"},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1406","type":"VBar"},{"attributes":{"active":1,"labels":["0","1"],"name":"Initial State"},"id":"1415","type":"RadioButtonGroup"},{"attributes":{},"id":"1399","type":"BasicTicker"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"1420"}]},"start":1,"title":"No. of Coins","value":0},"id":"1413","type":"Slider"},{"attributes":{},"id":"1396","type":"CategoricalTicker"},{"attributes":{"text":""},"id":"1424","type":"Title"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"1386","type":"DataRange1d"},{"attributes":{"axis":{"id":"1395"},"ticker":null},"id":"1397","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1402"}]},"id":"1403","type":"Toolbar"},{"attributes":{},"id":"1428","type":"CategoricalTickFormatter"},{"attributes":{"axis":{"id":"1398"},"dimension":1,"ticker":null},"id":"1401","type":"Grid"},{"attributes":{},"id":"1430","type":"Selection"},{"attributes":{"axis_label":"Counts","formatter":{"id":"1426"},"ticker":{"id":"1399"}},"id":"1398","type":"LinearAxis"},{"attributes":{"text":"Results:"},"id":"1417","type":"Div"},{"attributes":{},"id":"1426","type":"BasicTickFormatter"},{"attributes":{"level":"glyph","source":{"id":"1385"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"1410","type":"LabelSet"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"1418","type":"Div"},{"attributes":{"args":{"resultsHTML":{"id":"1418"},"results_label":{"id":"1417"},"source":{"id":"1385"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"1421","type":"CustomJS"},{"attributes":{},"id":"1431","type":"UnionRenderers"},{"attributes":{},"id":"1402","type":"ResetTool"},{"attributes":{"data_source":{"id":"1385"},"glyph":{"id":"1406"},"hover_glyph":null,"muted_glyph":null,"nonselection_gly ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('1512').textContent;
#                   var render_items = [{"docid":"18d8fab4-968d-4fa7-bbae-43bbb73378bd","root_ids":["1423"],"roots":{"1423":"0719a5e0-3d1a-46bd-ad9c-9fc4d3010778"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         }

# %% [markdown]
# And similarly, it looks like from a 1 state, the coin toss gives us a 50-50 chance of measuring 0 or 1. The probability tree looks like this:
#
# ![](images/whatis/whatis7.png)
#
# ### Experiment #4: The Double Quantum Coin Toss
#
# We now have a model that predicts the behaviour of the quantum coin. Like good scientists, we now want to test it on new scenarios and see if it holds up. Let’s try the double coin toss as we did before. Just like the classical coins, our model of the quantum coin predicts a 50-50 chance of measuring 0 or 1, regardless of which state we start in:
#
# ![](images/whatis/whatis8.png)

# %% [markdown]
# So let’s try it! We’re going to toss the quantum coin twice:

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# Define buttons and sliders
tossbtn = Button(label="Toss Quantum Coin Twice")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=0)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# Define callbacks
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label,
                                init_state_radio=init_state_radio), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = init_state_radio.active;
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Double Quantum Tosses):";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin Twice";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins Twice";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# Link callbacks to buttons / sliders
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# Compose Layout
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# Output HTML
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.1.1.min.js" integrity="sha384-kLr4fYcqcSpbuI95brIH3vnnYCquzzSxHPU6XGQCIkQRGJwhg0StNbj1eegrHs12" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.1.1.min.js" integrity="sha384-xIGPmVtaOm+z0BqfSOMn4lOR6ciex448GIKG4eE61LsAvmGj48XcMQZtKcE/UXZe" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="79a4d4bd-3a09-4fc2-a700-cf5aca21b190" data-root-id="1551"></div>
#
#
#
#
#
#         <script type="application/json" id="1640">
#           {"ab15ab28-b508-48d1-9c6e-c08381d9ae10":{"roots":{"references":[{"attributes":{},"id":"1530","type":"ResetTool"},{"attributes":{"data_source":{"id":"1513"},"glyph":{"id":"1534"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1535"},"selection_glyph":null,"view":{"id":"1537"}},"id":"1536","type":"GlyphRenderer"},{"attributes":{"source":{"id":"1513"}},"id":"1537","type":"CDSView"},{"attributes":{"children":[{"id":"1540"},{"id":"1541"},{"id":"1542"},{"id":"1543"},{"id":"1544"},{"id":"1545"},{"id":"1546"}]},"id":"1550","type":"Column"},{"attributes":{"active":0,"labels":["0","1"],"name":"Initial State"},"id":"1543","type":"RadioButtonGroup"},{"attributes":{"axis_label":"Counts","formatter":{"id":"1554"},"ticker":{"id":"1527"}},"id":"1526","type":"LinearAxis"},{"attributes":{"text":"Initial State:"},"id":"1542","type":"Div"},{"attributes":{"args":{"init_state_radio":{"id":"1543"},"p":{"id":"1515"},"resultsHTML":{"id":"1546"},"results_label":{"id":"1545"},"s":{"id":"1541"},"source":{"id":"1513"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = init_state_radio.active;\n            source.data.top[result] += 1;\n            resultsHTML.text += [' 0 ', ' 1 '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" Double Quantum Tosses):\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_range.range_padding_units = 'percent';\n            p.y_range.range_padding = 1;\n        } else {\n            p.y_range.range_padding_units = 'absolute';\n            p.y_range.range_padding = 30 - Math.max(...source.data.top);\n        };\n        source.change.emit();\n    "},"id":"1547","type":"CustomJS"},{"attributes":{"text":""},"id":"1552","type":"Title"},{"attributes":{},"id":"1519","type":"CategoricalScale"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"1548"}]},"start":1,"title":"No. of Coins","value":0},"id":"1541","type":"Slider"},{"attributes":{"axis":{"id":"1526"},"dimension":1,"ticker":null},"id":"1529","type":"Grid"},{"attributes":{"level":"glyph","source":{"id":"1513"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"1538","type":"LabelSet"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1535","type":"VBar"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1547"}]},"label":"Toss Quantum Coin Twice"},"id":"1540","type":"Button"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1549"}]},"label":"Reset"},"id":"1544","type":"Button"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"1558"},"selection_policy":{"id":"1559"}},"id":"1513","type":"ColumnDataSource"},{"attributes":{"factors":["0","1"]},"id":"1516","type":"FactorRange"},{"attributes":{},"id":"1556","type":"CategoricalTickFormatter"},{"attributes":{"below":[{"id":"1523"}],"center":[{"id":"1525"},{"id":"1529"},{"id":"1538"}],"left":[{"id":"1526"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"1536"}],"sizing_mode":"scale_width","title":{"id":"1552"},"toolbar":{"id":"1531"},"x_range":{"id":"1516"},"x_scale":{"id":"1519"},"y_range":{"id":"1514"},"y_scale":{"id":"1521"}},"id":"1515","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#BE95FF"},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1534","type":"VBar"},{"attributes":{},"i ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('1640').textContent;
#                   var render_items = [{"docid":"ab15ab28-b508-48d1-9c6e-c08381d9ae10","root_ids":["1551"],"roots":{"1551":"79a4d4bd-3a09-4fc2-a700-cf5aca21b190"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS librar

# %% [markdown]
# Hmm… this is an unexpected result. Let's see what happens when we set the initial state to 1:

# %%
data_labels = ["0", "1"]
initial_counts = [0]*2
initial_labels = ["0.00%"]*2

source = ColumnDataSource(data=dict(x=data_labels, top=initial_counts, top_percent=initial_labels))

plot = figure(
              plot_height=500, 
              plot_width=500,
              sizing_mode="scale_width",
              tools="reset",
              x_range=data_labels,
              y_range=DataRange1d(start=0, range_padding = 20, range_padding_units='absolute'),
              y_axis_label="Counts")
plot.vbar(top='top',x='x',width=0.5,source=source, color="#BE95FF")
labels = LabelSet(x='x', y='top', text='top_percent', level='glyph',
        x_offset=-20, y_offset=12, source=source, render_mode='canvas')
plot.add_layout(labels)



# Define buttons and sliders
tossbtn = Button(label="Toss Quantum Coin Twice")
repeat_slider = Slider(title="No. of Coins", start=1, end=50, step=1, value=0)
radio_label = Div(text="Initial State:")
init_state_radio = RadioButtonGroup(name="Initial State", labels=data_labels, active=1)
resetbtn = Button(label="Reset")
results_label = Div(text="Results:")
resultsHTML = Div(text="", style={'overflow-y': 'auto', 'max-height': '250px'})

# Define callbacks
toss_callback = CustomJS(args=dict(source=source, p=plot, 
                                   s=repeat_slider, 
                                   resultsHTML=resultsHTML, 
                                   results_label=results_label,
                                init_state_radio=init_state_radio), 
                code="""
        for (var i = 0; i <= s.value; ++i){
            const result = init_state_radio.active;
            source.data.top[result] += 1;
            resultsHTML.text += [' 0 ', ' 1 '][result]
        }
        const total_tosses = source.data.top[0] + source.data.top[1];
        results_label.text = "Results (" + total_tosses + " Quantum Tosses)";
        
        for (var i = 0; i<2; ++i){
            const frac = source.data.top[i] / source.data.top.reduce((a, b) => a + b, 0);
            source.data.top_percent[i] = (frac*100).toFixed(2) + "%";
        }
        if (Math.max(...source.data.top) > 22) {
            p.y_range.range_padding_units = 'percent';
            p.y_range.range_padding = 1;
        } else {
            p.y_range.range_padding_units = 'absolute';
            p.y_range.range_padding = 30 - Math.max(...source.data.top);
        };
        source.change.emit();
    """)

slider_callback = CustomJS(args=dict(tossbtn=tossbtn), 
                  code="""
    const repeats = cb_obj.value;
    if (repeats == 1) {
        tossbtn.label = "Toss Quantum Coin Twice";
    }
    else {
        tossbtn.label = "Toss " + repeats + " Quantum Coins Twice";
    };
    """)

reset_callback = CustomJS(args=dict(source=source, resultsHTML=resultsHTML, results_label=results_label), code="""
    source.data.top = [0,0];
    source.data.top_percent = ['0.00%', '0.00%'];
    source.change.emit();
    resultsHTML.text = "";
    results_label.text = "Results:";
    """)

# Link callbacks to buttons / sliders
tossbtn.js_on_event(ButtonClick, toss_callback)
repeat_slider.js_on_change('value', slider_callback)
resetbtn.js_on_event(ButtonClick, reset_callback)

# Compose Layout
control_panel = column(tossbtn, 
                       repeat_slider, 
                       radio_label, 
                       init_state_radio, 
                       resetbtn, 
                       results_label, 
                       resultsHTML)

layout = row(plot, control_panel)

# Output HTML
html_repr = file_html(layout, CDN)
IPython.display.HTML(html_repr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.1.1.min.js" integrity="sha384-kLr4fYcqcSpbuI95brIH3vnnYCquzzSxHPU6XGQCIkQRGJwhg0StNbj1eegrHs12" crossorigin="anonymous"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.1.1.min.js" integrity="sha384-xIGPmVtaOm+z0BqfSOMn4lOR6ciex448GIKG4eE61LsAvmGj48XcMQZtKcE/UXZe" crossorigin="anonymous"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="448b6e45-24c6-48ba-a4c9-70c6fd93c7c3" data-root-id="1679"></div>
#
#
#
#
#
#         <script type="application/json" id="1768">
#           {"62e886a9-ecd3-49df-a877-89d85cb71b13":{"roots":{"references":[{"attributes":{},"id":"1647","type":"CategoricalScale"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1675"}]},"label":"Toss Quantum Coin Twice"},"id":"1668","type":"Button"},{"attributes":{"data_source":{"id":"1641"},"glyph":{"id":"1662"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1663"},"selection_glyph":null,"view":{"id":"1665"}},"id":"1664","type":"GlyphRenderer"},{"attributes":{"level":"glyph","source":{"id":"1641"},"text":{"field":"top_percent"},"x":{"field":"x"},"x_offset":{"value":-20},"y":{"field":"top"},"y_offset":{"value":12}},"id":"1666","type":"LabelSet"},{"attributes":{"data":{"top":[0,0],"top_percent":["0.00%","0.00%"],"x":["0","1"]},"selected":{"id":"1686"},"selection_policy":{"id":"1687"}},"id":"1641","type":"ColumnDataSource"},{"attributes":{"range_padding":20,"range_padding_units":"absolute","start":0},"id":"1642","type":"DataRange1d"},{"attributes":{"args":{"resultsHTML":{"id":"1674"},"results_label":{"id":"1673"},"source":{"id":"1641"}},"code":"\n    source.data.top = [0,0];\n    source.data.top_percent = ['0.00%', '0.00%'];\n    source.change.emit();\n    resultsHTML.text = \"\";\n    results_label.text = \"Results:\";\n    "},"id":"1677","type":"CustomJS"},{"attributes":{"children":[{"id":"1643"},{"id":"1678"}]},"id":"1679","type":"Row"},{"attributes":{"formatter":{"id":"1684"},"ticker":{"id":"1652"}},"id":"1651","type":"CategoricalAxis"},{"attributes":{"end":50,"format":"0[.]00","js_property_callbacks":{"change:value":[{"id":"1676"}]},"start":1,"title":"No. of Coins","value":0},"id":"1669","type":"Slider"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#BE95FF"},"line_alpha":{"value":0.1},"line_color":{"value":"#BE95FF"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"1663","type":"VBar"},{"attributes":{"style":{"max-height":"250px","overflow-y":"auto"}},"id":"1674","type":"Div"},{"attributes":{},"id":"1652","type":"CategoricalTicker"},{"attributes":{"axis_label":"Counts","formatter":{"id":"1682"},"ticker":{"id":"1655"}},"id":"1654","type":"LinearAxis"},{"attributes":{"icon":null,"js_event_callbacks":{"button_click":[{"id":"1677"}]},"label":"Reset"},"id":"1672","type":"Button"},{"attributes":{"args":{"init_state_radio":{"id":"1671"},"p":{"id":"1643"},"resultsHTML":{"id":"1674"},"results_label":{"id":"1673"},"s":{"id":"1669"},"source":{"id":"1641"}},"code":"\n        for (var i = 0; i &lt;= s.value; ++i){\n            const result = init_state_radio.active;\n            source.data.top[result] += 1;\n            resultsHTML.text += [' 0 ', ' 1 '][result]\n        }\n        const total_tosses = source.data.top[0] + source.data.top[1];\n        results_label.text = \"Results (\" + total_tosses + \" Quantum Tosses)\";\n        \n        for (var i = 0; i&lt;2; ++i){\n            const frac = source.data.top[i] / source.data.top.reduce((a, b) =&gt; a + b, 0);\n            source.data.top_percent[i] = (frac*100).toFixed(2) + \"%\";\n        }\n        if (Math.max(...source.data.top) &gt; 22) {\n            p.y_range.range_padding_units = 'percent';\n            p.y_range.range_padding = 1;\n        } else {\n            p.y_range.range_padding_units = 'absolute';\n            p.y_range.range_padding = 30 - Math.max(...source.data.top);\n        };\n        source.change.emit();\n    "},"id":"1675","type":"CustomJS"},{"attributes":{},"id":"1686","type":"Selection"},{"attributes":{"text":"Results:"},"id":"1673","type":"Div"},{"attributes":{},"id":"1684","type":"CategoricalTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1658"}]},"id":"1659","type":"Toolbar"},{"attributes":{},"id":"1655","type":"BasicTicker"},{"attributes":{"active":1,"labels":["0","1"],"name":"Initial State"},"id":"1671","type":"RadioButtonGroup"},{"attributes":{"axis":{"id":"165 ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('1768').textContent;
#                   var render_items = [{"docid":"62e886a9-ecd3-49df-a877-89d85cb71b13","root_ids":["1679"],"roots":{"1679":"448b6e45-24c6-48ba-a4c9-70c6fd93c7c3"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is mis

# %% [markdown]
# This doesn't match our prediction at all! Our model has failed us! This is the same problem that physicists encountered in the early 20th century. Searching for the answer led to the development of quantum physics, which is what we will use to describe our quantum coin toss.
#
# ## The Quantum Model
#
# In short, quantum theory is probability theory with negative numbers.
#
# What does this mean? We can’t have negative probabilities as that doesn’t make sense. To accommodate this, we use a new quantity we call _amplitudes_ and plot these on trees instead. To get around the fact that we cannot have negative probabilities, and that all our probabilities must add up to 1, we use a mathematical trick: We square our amplitudes to calculate the probabilities.
#
# Let’s see an example. The amplitude trees for our single quantum coin toss look like this:
#
# ![](images/whatis/whatis9.png)
#
# We can see that starting in the state 0, the quantum coin toss assigns equal amplitudes to both outcomes. When we square these amplitudes, they give us the correct probability of measuring 0 or 1 (50-50 chance). How did we know that the amplitudes were $\sqrt{\tfrac{1}{2}}$? Because they're the values that give us the right answers!
#
# Starting in the state 1, the amplitude tree is different:
#
# ![](images/whatis/whatis10.png)
#
# Here we can see our first negative number appearing in the amplitude of the 1 outcome. When we square our amplitudes to calculate the probabilities, this negative sign disappears (remember that a negative times a negative is a positive), and we see the 50-50 chance we measured above. The interesting result is when we chain these probabilities together.

# %% [markdown]
# ## Explaining the Double Quantum Coin Toss
#
# Just like with classical probability, we multiply our amplitudes along the branches to calculate the amplitude of each outcome:
#
# ![](images/whatis/whatis11.gif)
#
# And to work out the probability of measuring each outcome, we add these amplitudes together, and then square them:
#
# ![](images/whatis/whatis12.gif)
#
# We can see the amplitudes of finding the coin (qubit) in the state 1 cancel each other out, and we call this effect interference. You should verify for yourself that this model works when the initial state is 1.

# %% [markdown]
# ## What is Quantum Computing?
#
#
# This is cool, but how is it useful? It turns out that these interference effects can be used to our advantage; we can combine operations such as the quantum coin toss to build more efficient algorithms. These algorithms can use interference effects to make the wrong answers cancel out quickly and give us a high probability of measuring the right answer. This is the idea behind quantum computing.
